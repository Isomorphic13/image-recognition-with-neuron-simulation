# %%
import numpy as np
import visualizer

current = 10
initial_state = np.array([-65, 0.3177, 0.0529, 0.5961])
dt = 0.01
time_array = np.arange(0,50, dt)

visualizer.visualise_state_of_single_neuron(initial_state, time_array, dt, current)

# %%
import numpy as np
import visualizer


initial_state = np.array([-65, 0.3177, 0.0529, 0.5961])
dt = 0.01
time_array = np.arange(0,50, dt)

visualizer.visualize_voltage_for_different_currents(initial_state, time_array, dt)

# %%
import numpy as np
import visualizer

visualizer.visualize_test( np.array([0.09, 0.09, -0.09, 0.09,0.04, -0.03]), 20)

# %%
import numpy as np
import visualizer

visualizer.visualize_test(np.load("optimal_weights.npy"), 50)

# %%
import numpy as np
import visualizer

visualizer.visualize_error_history(np.load("errors_history.npy"))
